# %% [markdown]
# **NAME : DASARI VENKATA RAMA KARTHIK**
#
# **ID NO : 190030372**
#
# **SC PRACTICAL 3**

# %%
pip install scikit-fuzzy

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz

# %% [markdown]
# #IN LAB
#
# **1. You have just learned what defuzzification is and the process of defuzzification. And you are
# interested to apply previous knowledge of fuzzy membership functions. So, implement a gaussian
# membership function with {c, α} = {3.5,1.5} and apply all the defuzzification processes to the
# generated membership function.**

# %%
 
# Generate gaussian membership function on range [0, 1]
x = np.arange(0, 5.05, 0.1)
mfx = fuzz.gaussmf(x,3.5,1.5)
 
# Defuzzify this membership function five ways
defuzz_centroid = fuzz.defuzz(x, mfx, 'centroid')  # Same as skfuzzy.centroid
defuzz_bisector = fuzz.defuzz(x, mfx, 'bisector')
defuzz_mom = fuzz.defuzz(x, mfx, 'mom')
defuzz_som = fuzz.defuzz(x, mfx, 'som')
defuzz_lom = fuzz.defuzz(x, mfx, 'lom')
 
# Collect info for vertical lines
labels = ['centroid', 'bisector', 'mean of maximum', 'min of maximum',
          'max of maximum']
xvals = [defuzz_centroid,
         defuzz_bisector,
         defuzz_mom,
         defuzz_som,
         defuzz_lom]

# %%
colors = ['r', 'b', 'g', 'c', 'm']
ymax = [fuzz.interp_membership(x, mfx, i) for i in xvals]
print(xvals)
print(ymax)
# Display and compare defuzzification results against membership function
plt.figure(figsize=(8, 5))
 
plt.plot(x, mfx, 'k')
for xv, y, label, color in zip(xvals, ymax, labels, colors):
    plt.vlines(xv, 0, y, label=label, color=color)
plt.ylabel('Fuzzy membership')
plt.xlabel('Universe variable (arb)')
plt.ylim(-0.1, 1.1)
plt.legend(loc=2)
 
plt.show()
# Out:
# [3.1105465747092924, 3.2183064637802974, 3.5, 3.5, 3.5]
# [0.9666647676654726, 0.9822035655830228, 1.0, 1.0, 1.0]

# %% [markdown]
# **2. Your friend has been assigned a work to write an assignment on the defuzzification of a triangular
# membership function using the bisector method. Help him in the implementation by framing a python
# code.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
# Generate triangular membership function on range [0, 1]
x = np.arange(0, 5.05, 0.1)
mfx = fuzz.trimf(x, [2, 3, 4.5])
# Defuzzify this membership function by bisector method
defuzz_bisector = fuzz.defuzz(x, mfx, 'bisector') 
# Collect info for vertical lines
labels = ['bisector']
xvals = [defuzz_bisector]
colors = ['r']
ymax = [fuzz.interp_membership(x, mfx, i) for i in xvals]
print(xvals)
print(ymax)
# Display and compare defuzzification results against membership function
plt.figure(figsize=(8, 5))
plt.plot(x, mfx, 'k')
for xv, y, label, color in zip(xvals, ymax, labels, colors):
    plt.vlines(xv, 0, y, label=label, color=color)
plt.ylabel('Fuzzy membership')
plt.xlabel('Universe variable (arb)')
plt.ylim(-0.1, 1.1)
plt.legend(loc=2)
plt.show()
# Out:
# [3.130693606237085]
# [0.9128709291752767]

# %% [markdown]
# #POST LAB
#
# **1.Ram wants your help to know the difference between the min of maxima and max of maxima in the
# implementation of defuzzification process. Help him to understand the difference by implementing a
# python code separately for both methods and visualize the membership function values and it’s
# defuzzification line.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
# Generate trapezoidal membership function on range [0, 1]
x = np.arange(0, 5.05, 0.1)
mfx = fuzz.trapmf(x, [2, 2.5, 3, 4.5])
# Defuzzify this membership function in min of maxima
defuzz_som  = fuzz.defuzz(x, mfx, 'som')
labels =['min of maximum']
xvals=[defuzz_som ]
colors =['g']
ymax = [fuzz.interp_membership(x, mfx, i) for i in xvals]
print(ymax)
print(xvals) 
# Display and compare defuzzification results against membership function
plt.figure(figsize=(8, 5))
plt.plot(x, mfx, 'k')
for xv, y, label, color in zip(xvals, ymax, labels, colors):
    plt.vlines(xv, 0, y, label=label, color=color)
plt.ylabel('Fuzzy membership')
plt.xlabel('Universe variable (arb)')
plt.ylim(-0.1, 1.1)
plt.legend(loc=2)
plt.show()
# Out:
# [1.0]
# [2.5]

# %% [markdown]
# 2.

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
# Generate trapezoidal membership function on range [0, 1]
x = np.arange(0, 5.05, 0.1)
mfx = fuzz.trapmf(x, [2, 2.5, 3, 4.5])
# Defuzzify this membership function in max of maxima
defuzz_lom  = fuzz.defuzz(x, mfx, 'lom')
labels =['max of maximum']
xvals=[defuzz_lom ]
colors =['g']
ymax = [fuzz.interp_membership(x, mfx, i) for i in xvals]
print(ymax)
print(xvals) 
# Display and compare defuzzification results against membership function
plt.figure(figsize=(8, 5))
plt.plot(x, mfx, 'k')
for xv, y, label, color in zip(xvals, ymax, labels, colors):
    plt.vlines(xv, 0, y, label=label, color=color)
plt.ylabel('Fuzzy membership')
plt.xlabel('Universe variable (arb)')
plt.ylim(-0.1, 1.1)
plt.legend(loc=2)
plt.show()
# Out:
# [1.0]
# [3.0]
